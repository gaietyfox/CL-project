# %% [markdown]
# <a href="https://colab.research.google.com/github/gaietyfox/CL-project/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_4_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание 4.

# %% [markdown]
# ## Часть 1. Парсинг телеграм-каналов
#
# У вас есть 3 файла на выбор в [этой папке](https://disk.360.yandex.ru/d/Zj9m22fARpgtHw):
# - Канал Системный Блокъ
# - Канал Нерусский мир
# - Канал RAntiquity
#
# В них сохранена история каналов за 2025 год в html-формате
#
# Подготовьте таблицу, в которой будет:
# - отправитель (у нас это будет канал - но в личных чатах туда попадает никнейм отправителя, как в ДЗ_3)
# - текст сообщения (его можно немного почистить (***по желанию***) - например, удалить из него тэги)
# - дата
# - (***по желанию***) реакции
#
# **Важно!** В этой выгрузке встречаются есть небольшие ошибки - посты без автора, без реакций и т.д. (можно отловить их и подумать, что с ними делать (проверка на None?), или использовать try / except, чтобы их просто проигнорировать)

# %% [markdown]
# Примерный результат выполнения всех заданий вы можете найти в той же [папке](https://disk.360.yandex.ru/d/Zj9m22fARpgtHw)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import codecs
import re

# %%
f = codecs.open("_НАЗВАНИЕ_.html", 'r', 'utf-8') # читаем код html из файла
telegram = f.read() # записываем его в переменную
f.close()

soup = BeautifulSoup(telegram)
soup

# %% [markdown]
# Лучше парсить через отдельные сообщения, чтобы количество авторов, текстов, дат, реакций совпало
# ```
# for i in soup.find_all(тэг):
#      i.find(тэг) # искать прямо в i
#      # i это 1 сообщение
# ```

# %%
for i in soup.find_all('div', {'class' : "message default clearfix"}):
    # ваш код

# %%
# ваш код ниже

# %% [markdown]
# ## Часть 2
#
# Парсинг сайта, на выбор:
# - [Детские вопросы](https://elementy.ru/email) в журнале "Элементы" (немного легче)
# - [Рубрика "Ускользающий мир"](https://www.nkj.ru/special/mir/) журнала "Наука и жизнь"

# %% [markdown]
# Общий алгоритм:
# - смотрим на 1 и последнюю страницу и с помощью range(от, до+1) генерируем ссылки на страницы
# - проходим по каждой странице и парсим ТОЛЬКО ссылки на новости (важно собрать нужные и очистить от лишних!). На момент начала задания было 88 Детских вопроса и 220 текстов Ускользающего мира (ближе к дедлайну их может стать немного больше)
# - переходим к каждой новости и парсим из нее:
#   - заголовок, автор ответа, текст, ссылку для Детских вопросов
#   - заголовок, дату, текст и ссылку для Ускользающего мира (***опционально*** - также автора, источник, тэги, но учтите, что они есть не в каждой статье -> проверка на None)
# - сохраняем результаты в датафрейм, не забудьте озаглавить столбцы
#
# Поскольку мы парсим реальные сайты, вежливый парсинг с time и задержкой в несколько секунд будет плюсом!

# %%
# ваш код
